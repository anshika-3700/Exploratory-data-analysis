# %% [markdown]
# 1. Import the customer data into python

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_table("Customers.csv",sep=",",encoding='latin1')
data.head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
#    Buy_Times  Points_Earned  Points_Redeemed
# ...

# %% [markdown]
# 2. Understand the data using different functions and attributes like shape, index,
# columns, dtypes.ndim, info(), get_dtype_counts etc.

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.index=np.arange(1,len(data)+1)

# %%
data.head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 1    129609144      M    20130130         West      Gujarat             Surat
# 2    129627580      M    20130129        North        Delhi             Delhi
# 3    130363481      M    20130221         West      Gujarat             Surat
# 4     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 5    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 1     20130216        West      Gujarat             Surat          2032.0
# 2     20130129       North        Delhi             Delhi          1709.0
# 3     20130221        West      Gujarat             Surat           523.0
# 4     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 5     20130301       North        Delhi             Delhi          1008.0
#
#    Buy_Times  Points_Earned  Points_Redeemed
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer_ID      10000 non-null  int64
#  1   Gender           9986 non-null   object
#  2   First_Date       10000 non-null  int64
#  3   First_region     9979 non-null   object
#  4   First_state      9983 non-null   object
#  5   First_city       10000 non-null  object
#  6   Recent_Date      10000 non-null  int64
#  7   Last_region      10000 non-null  object
#  8   Last_state       10000 non-null  object
#  9   Last_city        10000 non-null  object
#  10  Customer_Value   9964 non-null   float64
#  11  Buy_Times        10000 non-null  int64
#  12  Points_Earned    9979 non-null   float64
#  13  Points_Redeemed  9988 non-null   float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
data.dtypes.ndim
# Out:
# 1

# %%
len(data)-data.count()
# Out:
# Customer_ID         0
# Gender             14
# First_Date          0
# First_region       21
# First_state        17
# First_city          0
# Recent_Date         0
# Last_region         0
# Last_state          0
# Last_city           0
# Customer_Value     36
# Buy_Times           0
# Points_Earned      21
# Points_Redeemed    12
# dtype: int64

# %% [markdown]
# 3. What is percentage of missing values for customer Value variable?

# %%
(len(data.Customer_Value)-data.Customer_Value.count())*100/len(data)
# Out:
# 0.36

# %% [markdown]
# 4. Create two subsets with unique and duplicate values.

# %%
un=data[~data.Customer_ID.duplicated()]
du=data[data.Customer_ID.duplicated()]
len(un),len(du)
# Out:
# (9955, 45)

# %%
data.Customer_ID.nunique()
# Out:
# 9955

# %% [markdown]
# 5. Create data set with list of customers whose customer value greater than 10000.

# %%
data.loc[data.Customer_Value >10000].head()
# Out:
#     Customer_ID Gender  First_Date First_region    First_state  \
# 15      1610085      F    20120103        North          Delhi
# 16      7518872      M    20120104        North  Uttar Pradesh
# 19     63508964      M    20120106         West    Maharashtra
# 20     23667984      F    20120107         West    Maharashtra
# 21     84634600      M    20120108        South      Karnataka
#
#           First_city  Recent_Date Last_region     Last_state  \
# 15             Delhi     20121013       North          Delhi
# 16            Kanpur     20130123       North  Uttar Pradesh
# 19  Pimpri-Chinchwad     20130222        West    Maharashtra
# 20            Nagpur     20130313        West    Maharashtra
# 21         Bangalore     20130307       South      Karnataka
#
#            Last_city  Customer_Value  Buy_Times  Points_Earned  \
# 15             Delhi       10380.199          6         1189.0
# 16            Kanpur       14587.000          6          865.0
# ...

# %% [markdown]
# 6. In customer table, create a new variable called “customer value segment” using
# customer value as follows. -
#  - High Value Segment - > 25000
#  - Medium Value Segment – Between 10000 and 25000
#  - Low Value Segment – less than or equal to 10000

# %%
cv=data.Customer_Value
data["cust_val_seg"]=np.where((cv > 25000) ,'high', np.where((cv > 10000) & (cv <= 25000), 'medium', 'low'))
data.head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 1    129609144      M    20130130         West      Gujarat             Surat
# 2    129627580      M    20130129        North        Delhi             Delhi
# 3    130363481      M    20130221         West      Gujarat             Surat
# 4     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 5    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 1     20130216        West      Gujarat             Surat          2032.0
# 2     20130129       North        Delhi             Delhi          1709.0
# 3     20130221        West      Gujarat             Surat           523.0
# 4     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 5     20130301       North        Delhi             Delhi          1008.0
#
# ...

# %% [markdown]
# 7. Create variables “average revenue per trip” and “balance points” in the customer
# data set.

# %%
data=data.assign(average_revenue_per_trip= data.Customer_Value/data.Buy_Times,
                  Balance_Points=data.Points_Earned - data.Points_Redeemed )
data.head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 1    129609144      M    20130130         West      Gujarat             Surat
# 2    129627580      M    20130129        North        Delhi             Delhi
# 3    130363481      M    20130221         West      Gujarat             Surat
# 4     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 5    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 1     20130216        West      Gujarat             Surat          2032.0
# 2     20130129       North        Delhi             Delhi          1709.0
# 3     20130221        West      Gujarat             Surat           523.0
# 4     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 5     20130301       North        Delhi             Delhi          1008.0
#
# ...

# %% [markdown]
# 8. How many days between last purchase date and today?

# %%
from datetime import datetime
fd=data.First_Date
ld=data.Recent_Date
data.First_Date=pd.to_datetime(data.First_Date,format="%Y%m%d")
data.Recent_Date=pd.to_datetime(data.Recent_Date,format="%Y%m%d")
data.head()
# Out:
#    Customer_ID Gender First_Date First_region  First_state        First_city  \
# 1    129609144      M 2013-01-30         West      Gujarat             Surat
# 2    129627580      M 2013-01-29        North        Delhi             Delhi
# 3    130363481      M 2013-02-21         West      Gujarat             Surat
# 4     49817480      M 2013-02-22         West  Maharashtra  Pimpri-Chinchwad
# 5    126343829      F 2013-03-01        North        Delhi             Delhi
#
#   Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 1  2013-02-16        West      Gujarat             Surat          2032.0
# 2  2013-01-29       North        Delhi             Delhi          1709.0
# 3  2013-02-21        West      Gujarat             Surat           523.0
# 4  2013-02-22        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 5  2013-03-01       North        Delhi             Delhi          1008.0
#
#    Buy_Times  Points_Earned  Points_Redeemed cust_val_seg  \
# ...

# %%
today=datetime.now().date()
today=pd.to_datetime(today,format="%Y-%m-%d")
today
# Out:
# Timestamp('2021-02-22 00:00:00')

# %%
data["dd"]=pd.to_datetime(today,format="%Y-%m-%d")-data.Recent_Date
data.dd.head()
# Out:
# 1   2928 days
# 2   2946 days
# 3   2923 days
# 4   2922 days
# 5   2915 days
# Name: dd, dtype: timedelta64[ns]

# %% [markdown]
# 9. Calculate percentage of sales by each last city, state and region.

# %%
data.groupby(["Last_region","Last_state","Last_city"])[["Customer_Value"]].sum()*100/data.Customer_Value.sum()
# Out:
#                                           Customer_Value
# Last_region Last_state  Last_city
# East        Assam       Guwahati                1.557344
#             Bihar       Begusarai               0.020559
#                         Bhagalpur               0.002230
#                         Katihar                 0.046883
#                         Patna                   0.185101
# ...                                                  ...
# West        Maharashtra Navi Mumbai             0.010617
#                         Pimpri-Chinchwad        3.314578
#                         Thane                   0.237204
#                         Ulhasnagar              0.005667
#                         Vasai-Virar             0.085952
#
# [116 rows x 1 columns]

# %% [markdown]
# 10. What is the count of customers, average number of purchases and average
# purchase transaction value by last state and city.

# %%
q1=data.groupby(["Last_state","Last_city"])[["Customer_ID"]].count().add_prefix("count_")

# %%
q2=data.groupby(["Last_state","Last_city"])[["Buy_Times"]].sum()

# %%
q3=data.groupby(["Last_state","Last_city"])[["average_revenue_per_trip"]].mean()

# %%
pd.merge(q1,q2,on=["Last_state","Last_city"],how="inner")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-4f17586e8032> in <module>
# ----> 1 pd.merge(q1,q2,q3,on=["Last_state","Last_city"],how="inner")
#
# TypeError: merge() got multiple values for argument 'how'
